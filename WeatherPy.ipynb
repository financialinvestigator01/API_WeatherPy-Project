# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Use Openweather api to get the weather data needed from those cities.
url = "http://api.openweathermap.org/data/2.5/weather?"
names = []
cloudiness = []
country = []
dates = []
humidity = []
lats = []
lons = []
max_temps = []
wind_speed = []

counter = 1

# Build query URL
for city in cities:
    
    try:
        query_url = url + "appid=" + api_key + "&q=" + city + "&units=imperial"
        response = requests.get(query_url).json()
        names.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        dates.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lats.append(response["coord"]["lat"])
        lons.append(response["coord"]["lon"])
        max_temps.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        print(f"Processing Record {counter} | {city}")
        print(f"{url}&q={city}")
        
        counter += 1
        
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Processing Record 1 | salalah
# http://api.openweathermap.org/data/2.5/weather?&q=salalah
# Processing Record 2 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?&q=saskylakh
# City not found. Skipping...
# Processing Record 3 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?&q=punta arenas
# Processing Record 4 | aswan
# http://api.openweathermap.org/data/2.5/weather?&q=aswan
# Processing Record 5 | ayan
# http://api.openweathermap.org/data/2.5/weather?&q=ayan
# Processing Record 6 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?&q=san cristobal
# Processing Record 7 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?&q=carnarvon
# Processing Record 8 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?&q=tuktoyaktuk
# Processing Record 9 | jamestown
# http://api.openweathermap.org/data/2.5/weather?&q=jamestown
# Processing Record 10 | busselton
# http://api.openweathermap.org/data/2.5/weather?&q=busselton
# Processing Record 11 | bafoussam
# http://api.openweathermap.org/data/2.5/weather?&q=bafoussam
# Processing Record 12 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?&q=hithadhoo
# Processing Record 13 | vagur
# http://api.openweathermap.org/data/2.5/weather?&q=vagur
# Processing Record 14 | bluff
# http://api.openweathermap.org/data/2.5/weather?&q=bluff
# Processing Record 15 | hilo
# http://api.openweathermap.org/data/2.5/weather?&q=hilo
# City not found. Skipping...
# Processing Record 16 | butaritari
# http://api.openweathermap.org/data/2.5/weather?&q=butaritari
# Processing Record 17 | upernavik
# http://api.openweathermap.org/data/2.5/weather?&q=upernavik
# Processing Record 18 | aguimes
# http://api.openweathermap.org/data/2.5/weather?&q=aguimes
# Processing Record 19 | tanout
# http://api.openweathermap.org/data/2.5/weather?&q=tanout
# City not found. Skipping...
# Processing Record 20 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?&q=yellowknife
# Processing Record 21 | norman wells
# http://api.openweathermap.org/data/2.5/weather?&q=norman wells
# Processing Record 22 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?&q=puerto ayora
# City not found. Skipping...
# Processing Record 23 | kodiak
# http://api.openweathermap.org/data/2.5/weather?&q=kodiak
# Processing Record 24 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?&q=qaanaaq
# City not found. Skipping...
# Processing Record 25 | morden
# http://api.openweathermap.org/data/2.5/weather?&q=morden
# Processing Record 26 | hay river
# http://api.openweathermap.org/data/2.5/weather?&q=hay river
# Processing Record 27 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?&q=ushuaia
# Processing Record 28 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?&q=fairbanks
# Processing Record 29 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?&q=alta floresta
# Processing Record 30 | jimma
# http://api.openweathermap.org/data/2.5/weather?&q=jimma
# Processing Record 31 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?&q=saint-philippe
# Processing Record 32 | portland
# http://api.openweathermap.org/data/2.5/weather?&q=portland
# Processing Record 33 | rio grande
# http://api.openweathermap.org/data/2.5/weather?&q=rio grande
# Processing Record 34 | rikitea
# http://api.openweathermap.org/data/2.5/weather?&q=rikitea
# Processing Record 35 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?&q=leningradskiy
# Processing Record 36 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?&q=port-gentil
# Processing Record 37 | kristinehamn
# http://api.openweathermap.org/data/2.5/weather?&q=kristinehamn
# City not found. Skipping...
# Processing Record 38 | north myrtle beach
# http://api.openweathermap.org/data/2.5/weather?&q=north myrtle beach
# Processing Record 39 | saint-dizier
# http://api.openweathermap.org/data/2.5/weather?&q=saint-dizier
# Processing Record 40 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?&q=lavrentiya
# Processing Record 41 | terrace
# http://api.openweathermap.org/data/2.5/weather?&q=terrace
# Processing Record 42 | mataura
# http://api.openweathermap.org/data/2.5/weather?&q=mataura
# Processing Record 43 | hobart
# http://api.openweathermap.org/data/2.5/weather?&q=hobart
# Processing Record 44 | avarua
# http://api.openweathermap.org/data/2.5/weather?&q=avarua
# Processing Record 45 | russell
# http://api.openweathermap.org/data/2.5/weather?&q=russell
# Processing Record 46 | itarema
# http://api.openweathermap.org/data/2.5/weather?&q=itarema
# Processing Record 47 | fortuna
# http://api.openweathermap.org/data/2.5/weather?&q=fortuna
# Processing Record 48 | kalabo
# http://api.openweathermap.org/data/2.5/weather?&q=kalabo
# Processing Record 49 | dingle
# http://api.openweathermap.org/data/2.5/weather?&q=dingle
# Processing Record 50 | danane
# http://api.openweathermap.org/data/2.5/weather?&q=danane
# Processing Record 51 | albany
# http://api.openweathermap.org/data/2.5/weather?&q=albany
# Processing Record 52 | port alfred
# http://api.openweathermap.org/data/2.5/weather?&q=port alfred
# Processing Record 53 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?&q=bredasdorp
# City not found. Skipping...
# Processing Record 54 | slave lake
# http://api.openweathermap.org/data/2.5/weather?&q=slave lake
# Processing Record 55 | kapaa
# http://api.openweathermap.org/data/2.5/weather?&q=kapaa
# Processing Record 56 | tateyama
# http://api.openweathermap.org/data/2.5/weather?&q=tateyama
# Processing Record 57 | leopold
# http://api.openweathermap.org/data/2.5/weather?&q=leopold
# Processing Record 58 | rumford
# http://api.openweathermap.org/data/2.5/weather?&q=rumford
# Processing Record 59 | kiama
# http://api.openweathermap.org/data/2.5/weather?&q=kiama
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 60 | mount isa
# http://api.openweathermap.org/data/2.5/weather?&q=mount isa
# Processing Record 61 | khatanga
# http://api.openweathermap.org/data/2.5/weather?&q=khatanga
# Processing Record 62 | hami
# http://api.openweathermap.org/data/2.5/weather?&q=hami
# Processing Record 63 | luderitz
# http://api.openweathermap.org/data/2.5/weather?&q=luderitz
# Processing Record 64 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?&q=arraial do cabo
# Processing Record 65 | hamilton
# http://api.openweathermap.org/data/2.5/weather?&q=hamilton
# Processing Record 66 | ibra
# http://api.openweathermap.org/data/2.5/weather?&q=ibra
# City not found. Skipping...
# Processing Record 67 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?&q=pacific grove
# Processing Record 68 | shimanovsk
# http://api.openweathermap.org/data/2.5/weather?&q=shimanovsk
# Processing Record 69 | camoapa
# http://api.openweathermap.org/data/2.5/weather?&q=camoapa
# Processing Record 70 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?&q=new norfolk
# Processing Record 71 | juba
# http://api.openweathermap.org/data/2.5/weather?&q=juba
# Processing Record 72 | lebu
# http://api.openweathermap.org/data/2.5/weather?&q=lebu
# Processing Record 73 | tambo
# http://api.openweathermap.org/data/2.5/weather?&q=tambo
# City not found. Skipping...
# Processing Record 74 | eyl
# http://api.openweathermap.org/data/2.5/weather?&q=eyl
# Processing Record 75 | flinders
# http://api.openweathermap.org/data/2.5/weather?&q=flinders
# Processing Record 76 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?&q=mahebourg
# Processing Record 77 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?&q=cabo san lucas
# Processing Record 78 | cape town
# http://api.openweathermap.org/data/2.5/weather?&q=cape town
# Processing Record 79 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?&q=mar del plata
# City not found. Skipping...
# Processing Record 80 | victor harbor
# http://api.openweathermap.org/data/2.5/weather?&q=victor harbor
# Processing Record 81 | huron
# http://api.openweathermap.org/data/2.5/weather?&q=huron
# City not found. Skipping...
# Processing Record 82 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?&q=yar-sale
# City not found. Skipping...
# Processing Record 83 | sidney
# http://api.openweathermap.org/data/2.5/weather?&q=sidney
# Processing Record 84 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?&q=whitehorse
# Processing Record 85 | dikson
# http://api.openweathermap.org/data/2.5/weather?&q=dikson
# Processing Record 86 | vila velha
# http://api.openweathermap.org/data/2.5/weather?&q=vila velha
# Processing Record 87 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?&q=ribeira grande
# Processing Record 88 | japoata
# http://api.openweathermap.org/data/2.5/weather?&q=japoata
# Processing Record 89 | pevek
# http://api.openweathermap.org/data/2.5/weather?&q=pevek
# Processing Record 90 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?&q=nikolskoye
# Processing Record 91 | tiksi
# http://api.openweathermap.org/data/2.5/weather?&q=tiksi
# Processing Record 92 | vaini
# http://api.openweathermap.org/data/2.5/weather?&q=vaini
# Processing Record 93 | misratah
# http://api.openweathermap.org/data/2.5/weather?&q=misratah
# Processing Record 94 | japura
# http://api.openweathermap.org/data/2.5/weather?&q=japura
# Processing Record 95 | guntakal
# http://api.openweathermap.org/data/2.5/weather?&q=guntakal
# Processing Record 96 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?&q=saint-pierre
# Processing Record 97 | burns lake
# http://api.openweathermap.org/data/2.5/weather?&q=burns lake
# Processing Record 98 | sitka
# http://api.openweathermap.org/data/2.5/weather?&q=sitka
# City not found. Skipping...
# Processing Record 99 | haines junction
# http://api.openweathermap.org/data/2.5/weather?&q=haines junction
# Processing Record 100 | gejiu
# http://api.openweathermap.org/data/2.5/weather?&q=gejiu
# City not found. Skipping...
# Processing Record 101 | the valley
# http://api.openweathermap.org/data/2.5/weather?&q=the valley
# Processing Record 102 | dicabisagan
# http://api.openweathermap.org/data/2.5/weather?&q=dicabisagan
# Processing Record 103 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?&q=kruisfontein
# Processing Record 104 | kahului
# http://api.openweathermap.org/data/2.5/weather?&q=kahului
# Processing Record 105 | susangerd
# http://api.openweathermap.org/data/2.5/weather?&q=susangerd
# Processing Record 106 | dharchula
# http://api.openweathermap.org/data/2.5/weather?&q=dharchula
# Processing Record 107 | irtyshskiy
# http://api.openweathermap.org/data/2.5/weather?&q=irtyshskiy
# Processing Record 108 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?&q=vestmannaeyjar
# Processing Record 109 | olive branch
# http://api.openweathermap.org/data/2.5/weather?&q=olive branch
# Processing Record 110 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?&q=coquimbo
# City not found. Skipping...
# Processing Record 111 | cuauhtemoc
# http://api.openweathermap.org/data/2.5/weather?&q=cuauhtemoc
# Processing Record 112 | gillette
# http://api.openweathermap.org/data/2.5/weather?&q=gillette
# Processing Record 113 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?&q=bambous virieux
# Processing Record 114 | hermanus
# http://api.openweathermap.org/data/2.5/weather?&q=hermanus
# Processing Record 115 | mayo
# http://api.openweathermap.org/data/2.5/weather?&q=mayo
# Processing Record 116 | barrow
# http://api.openweathermap.org/data/2.5/weather?&q=barrow
# Processing Record 117 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?&q=mandalgovi
# Processing Record 118 | esperance
# http://api.openweathermap.org/data/2.5/weather?&q=esperance
# Processing Record 119 | lorengau
# http://api.openweathermap.org/data/2.5/weather?&q=lorengau
# Processing Record 120 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?&q=tasiilaq
# Processing Record 121 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?&q=srednekolymsk
# Processing Record 122 | hays
# http://api.openweathermap.org/data/2.5/weather?&q=hays
# Processing Record 123 | beitbridge
# http://api.openweathermap.org/data/2.5/weather?&q=beitbridge
# Processing Record 124 | husavik
# http://api.openweathermap.org/data/2.5/weather?&q=husavik
# City not found. Skipping...
# Processing Record 125 | kapuvar
# http://api.openweathermap.org/data/2.5/weather?&q=kapuvar
# Processing Record 126 | lugovoy
# http://api.openweathermap.org/data/2.5/weather?&q=lugovoy
# Processing Record 127 | sumbe
# http://api.openweathermap.org/data/2.5/weather?&q=sumbe
# Processing Record 128 | beyneu
# http://api.openweathermap.org/data/2.5/weather?&q=beyneu
# Processing Record 129 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?&q=cockburn town
# Processing Record 130 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?&q=chokurdakh
# Processing Record 131 | berlevag
# http://api.openweathermap.org/data/2.5/weather?&q=berlevag
# Processing Record 132 | nuuk
# http://api.openweathermap.org/data/2.5/weather?&q=nuuk
# Processing Record 133 | anqing
# http://api.openweathermap.org/data/2.5/weather?&q=anqing
# Processing Record 134 | nizwa
# http://api.openweathermap.org/data/2.5/weather?&q=nizwa
# Processing Record 135 | east london
# http://api.openweathermap.org/data/2.5/weather?&q=east london
# Processing Record 136 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?&q=longyearbyen
# Processing Record 137 | akureyri
# http://api.openweathermap.org/data/2.5/weather?&q=akureyri
# Processing Record 138 | opuwo
# http://api.openweathermap.org/data/2.5/weather?&q=opuwo
# Processing Record 139 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?&q=klaksvik
# Processing Record 140 | chanute
# http://api.openweathermap.org/data/2.5/weather?&q=chanute
# Processing Record 141 | port blair
# http://api.openweathermap.org/data/2.5/weather?&q=port blair
# Processing Record 142 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?&q=grand gaube
# Processing Record 143 | bethel
# http://api.openweathermap.org/data/2.5/weather?&q=bethel
# Processing Record 144 | noumea
# http://api.openweathermap.org/data/2.5/weather?&q=noumea
# Processing Record 145 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?&q=komsomolskiy
# Processing Record 146 | beterou
# http://api.openweathermap.org/data/2.5/weather?&q=beterou
# Processing Record 147 | timon
# http://api.openweathermap.org/data/2.5/weather?&q=timon
# Processing Record 148 | hofn
# http://api.openweathermap.org/data/2.5/weather?&q=hofn
# Processing Record 149 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?&q=quatre cocos
# Processing Record 150 | narsaq
# http://api.openweathermap.org/data/2.5/weather?&q=narsaq
# Processing Record 151 | torbay
# http://api.openweathermap.org/data/2.5/weather?&q=torbay
# Processing Record 152 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?&q=ponta do sol
# Processing Record 153 | uaua
# http://api.openweathermap.org/data/2.5/weather?&q=uaua
# Processing Record 154 | richards bay
# http://api.openweathermap.org/data/2.5/weather?&q=richards bay
# Processing Record 155 | poprad
# http://api.openweathermap.org/data/2.5/weather?&q=poprad
# Processing Record 156 | marawi
# http://api.openweathermap.org/data/2.5/weather?&q=marawi
# Processing Record 157 | kuopio
# http://api.openweathermap.org/data/2.5/weather?&q=kuopio
# Processing Record 158 | pisco
# http://api.openweathermap.org/data/2.5/weather?&q=pisco
# Processing Record 159 | touros
# http://api.openweathermap.org/data/2.5/weather?&q=touros
# Processing Record 160 | vanimo
# http://api.openweathermap.org/data/2.5/weather?&q=vanimo
# Processing Record 161 | skjervoy
# http://api.openweathermap.org/data/2.5/weather?&q=skjervoy
# Processing Record 162 | alice springs
# http://api.openweathermap.org/data/2.5/weather?&q=alice springs
# Processing Record 163 | junin
# http://api.openweathermap.org/data/2.5/weather?&q=junin
# Processing Record 164 | potsdam
# http://api.openweathermap.org/data/2.5/weather?&q=potsdam
# Processing Record 165 | parintins
# http://api.openweathermap.org/data/2.5/weather?&q=parintins
# Processing Record 166 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?&q=pangnirtung
# Processing Record 167 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?&q=tuatapere
# Processing Record 168 | katsuura
# http://api.openweathermap.org/data/2.5/weather?&q=katsuura
# City not found. Skipping...
# Processing Record 169 | cayon
# http://api.openweathermap.org/data/2.5/weather?&q=cayon
# Processing Record 170 | klyuchi
# http://api.openweathermap.org/data/2.5/weather?&q=klyuchi
# Processing Record 171 | orlik
# http://api.openweathermap.org/data/2.5/weather?&q=orlik
# Processing Record 172 | necochea
# http://api.openweathermap.org/data/2.5/weather?&q=necochea
# Processing Record 173 | lompoc
# http://api.openweathermap.org/data/2.5/weather?&q=lompoc
# Processing Record 174 | belfast
# http://api.openweathermap.org/data/2.5/weather?&q=belfast
# Processing Record 175 | bowen
# http://api.openweathermap.org/data/2.5/weather?&q=bowen
# Processing Record 176 | waipawa
# http://api.openweathermap.org/data/2.5/weather?&q=waipawa
# Processing Record 177 | mecca
# http://api.openweathermap.org/data/2.5/weather?&q=mecca
# Processing Record 178 | yinchuan
# http://api.openweathermap.org/data/2.5/weather?&q=yinchuan
# Processing Record 179 | turayf
# http://api.openweathermap.org/data/2.5/weather?&q=turayf
# Processing Record 180 | geraldton
# http://api.openweathermap.org/data/2.5/weather?&q=geraldton
# Processing Record 181 | porlamar
# http://api.openweathermap.org/data/2.5/weather?&q=porlamar
# Processing Record 182 | mindyak
# http://api.openweathermap.org/data/2.5/weather?&q=mindyak
# Processing Record 183 | atbasar
# http://api.openweathermap.org/data/2.5/weather?&q=atbasar
# Processing Record 184 | wonthaggi
# http://api.openweathermap.org/data/2.5/weather?&q=wonthaggi
# Processing Record 185 | thompson
# http://api.openweathermap.org/data/2.5/weather?&q=thompson
# Processing Record 186 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?&q=severo-kurilsk
# Processing Record 187 | rosetta
# http://api.openweathermap.org/data/2.5/weather?&q=rosetta
# Processing Record 188 | chipinge
# http://api.openweathermap.org/data/2.5/weather?&q=chipinge
# Processing Record 189 | pemberton
# http://api.openweathermap.org/data/2.5/weather?&q=pemberton
# Processing Record 190 | pochutla
# http://api.openweathermap.org/data/2.5/weather?&q=pochutla
# Processing Record 191 | okha
# http://api.openweathermap.org/data/2.5/weather?&q=okha
# Processing Record 192 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?&q=ilulissat
# Processing Record 193 | sheltozero
# http://api.openweathermap.org/data/2.5/weather?&q=sheltozero
# Processing Record 194 | vaitape
# http://api.openweathermap.org/data/2.5/weather?&q=vaitape
# Processing Record 195 | dudinka
# http://api.openweathermap.org/data/2.5/weather?&q=dudinka
# Processing Record 196 | hambantota
# http://api.openweathermap.org/data/2.5/weather?&q=hambantota
# Processing Record 197 | manokwari
# http://api.openweathermap.org/data/2.5/weather?&q=manokwari
# Processing Record 198 | saldanha
# http://api.openweathermap.org/data/2.5/weather?&q=saldanha
# Processing Record 199 | tyukalinsk
# http://api.openweathermap.org/data/2.5/weather?&q=tyukalinsk
# Processing Record 200 | the pas
# http://api.openweathermap.org/data/2.5/weather?&q=the pas
# Processing Record 201 | pasighat
# http://api.openweathermap.org/data/2.5/weather?&q=pasighat
# Processing Record 202 | asmara
# http://api.openweathermap.org/data/2.5/weather?&q=asmara
# Processing Record 203 | qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?&q=qasigiannguit
# Processing Record 204 | muros
# http://api.openweathermap.org/data/2.5/weather?&q=muros
# Processing Record 205 | te anau
# http://api.openweathermap.org/data/2.5/weather?&q=te anau
# City not found. Skipping...
# Processing Record 206 | broome
# http://api.openweathermap.org/data/2.5/weather?&q=broome
# Processing Record 207 | faanui
# http://api.openweathermap.org/data/2.5/weather?&q=faanui
# Processing Record 208 | atuona
# http://api.openweathermap.org/data/2.5/weather?&q=atuona
# Processing Record 209 | yenagoa
# http://api.openweathermap.org/data/2.5/weather?&q=yenagoa
# Processing Record 210 | yarmouth
# http://api.openweathermap.org/data/2.5/weather?&q=yarmouth
# Processing Record 211 | orel-izumrud
# http://api.openweathermap.org/data/2.5/weather?&q=orel-izumrud
# Processing Record 212 | san quintin
# http://api.openweathermap.org/data/2.5/weather?&q=san quintin
# Processing Record 213 | biak
# http://api.openweathermap.org/data/2.5/weather?&q=biak
# Processing Record 214 | rock sound
# http://api.openweathermap.org/data/2.5/weather?&q=rock sound
# Processing Record 215 | beyla
# http://api.openweathermap.org/data/2.5/weather?&q=beyla
# Processing Record 216 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?&q=iqaluit
# Processing Record 217 | nishihara
# http://api.openweathermap.org/data/2.5/weather?&q=nishihara
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 218 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?&q=saint-augustin
# Processing Record 219 | dakar
# http://api.openweathermap.org/data/2.5/weather?&q=dakar
# City not found. Skipping...
# Processing Record 220 | port hedland
# http://api.openweathermap.org/data/2.5/weather?&q=port hedland
# Processing Record 221 | kieta
# http://api.openweathermap.org/data/2.5/weather?&q=kieta
# Processing Record 222 | nemuro
# http://api.openweathermap.org/data/2.5/weather?&q=nemuro
# Processing Record 223 | la ronge
# http://api.openweathermap.org/data/2.5/weather?&q=la ronge
# Processing Record 224 | tawang
# http://api.openweathermap.org/data/2.5/weather?&q=tawang
# City not found. Skipping...
# Processing Record 225 | viedma
# http://api.openweathermap.org/data/2.5/weather?&q=viedma
# Processing Record 226 | kaeo
# http://api.openweathermap.org/data/2.5/weather?&q=kaeo
# Processing Record 227 | grindavik
# http://api.openweathermap.org/data/2.5/weather?&q=grindavik
# Processing Record 228 | acapulco
# http://api.openweathermap.org/data/2.5/weather?&q=acapulco
# Processing Record 229 | bombay
# http://api.openweathermap.org/data/2.5/weather?&q=bombay
# Processing Record 230 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?&q=zhigansk
# Processing Record 231 | port-cartier
# http://api.openweathermap.org/data/2.5/weather?&q=port-cartier
# Processing Record 232 | strathpeffer
# http://api.openweathermap.org/data/2.5/weather?&q=strathpeffer
# Processing Record 233 | saint george
# http://api.openweathermap.org/data/2.5/weather?&q=saint george
# Processing Record 234 | byron bay
# http://api.openweathermap.org/data/2.5/weather?&q=byron bay
# Processing Record 235 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?&q=vila franca do campo
# Processing Record 236 | galle
# http://api.openweathermap.org/data/2.5/weather?&q=galle
# Processing Record 237 | darasun
# http://api.openweathermap.org/data/2.5/weather?&q=darasun
# Processing Record 238 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?&q=prince rupert
# Processing Record 239 | regente feijo
# http://api.openweathermap.org/data/2.5/weather?&q=regente feijo
# Processing Record 240 | talnakh
# http://api.openweathermap.org/data/2.5/weather?&q=talnakh
# Processing Record 241 | cayenne
# http://api.openweathermap.org/data/2.5/weather?&q=cayenne
# Processing Record 242 | tessalit
# http://api.openweathermap.org/data/2.5/weather?&q=tessalit
# Processing Record 243 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?&q=port elizabeth
# Processing Record 244 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?&q=meulaboh
# Processing Record 245 | tazmalt
# http://api.openweathermap.org/data/2.5/weather?&q=tazmalt
# Processing Record 246 | hallein
# http://api.openweathermap.org/data/2.5/weather?&q=hallein
# Processing Record 247 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?&q=bandarbeyla
# City not found. Skipping...
# Processing Record 248 | provideniya
# http://api.openweathermap.org/data/2.5/weather?&q=provideniya
# Processing Record 249 | yokadouma
# http://api.openweathermap.org/data/2.5/weather?&q=yokadouma
# Processing Record 250 | north platte
# http://api.openweathermap.org/data/2.5/weather?&q=north platte
# Processing Record 251 | san patricio
# http://api.openweathermap.org/data/2.5/weather?&q=san patricio
# Processing Record 252 | totana
# http://api.openweathermap.org/data/2.5/weather?&q=totana
# Processing Record 253 | aykhal
# http://api.openweathermap.org/data/2.5/weather?&q=aykhal
# Processing Record 254 | yabrud
# http://api.openweathermap.org/data/2.5/weather?&q=yabrud
# Processing Record 255 | saint-georges
# http://api.openweathermap.org/data/2.5/weather?&q=saint-georges
# Processing Record 256 | georgetown
# http://api.openweathermap.org/data/2.5/weather?&q=georgetown
# Processing Record 257 | wewak
# http://api.openweathermap.org/data/2.5/weather?&q=wewak
# Processing Record 258 | codrington
# http://api.openweathermap.org/data/2.5/weather?&q=codrington
# Processing Record 259 | newport
# http://api.openweathermap.org/data/2.5/weather?&q=newport
# Processing Record 260 | guanica
# http://api.openweathermap.org/data/2.5/weather?&q=guanica
# City not found. Skipping...
# Processing Record 261 | gravdal
# http://api.openweathermap.org/data/2.5/weather?&q=gravdal
# Processing Record 262 | poronaysk
# http://api.openweathermap.org/data/2.5/weather?&q=poronaysk
# Processing Record 263 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?&q=mogadishu
# Processing Record 264 | chama
# http://api.openweathermap.org/data/2.5/weather?&q=chama
# Processing Record 265 | krasnogvardeyskiy
# http://api.openweathermap.org/data/2.5/weather?&q=krasnogvardeyskiy
# Processing Record 266 | chapais
# http://api.openweathermap.org/data/2.5/weather?&q=chapais
# Processing Record 267 | lagoa
# http://api.openweathermap.org/data/2.5/weather?&q=lagoa
# Processing Record 268 | chemal
# http://api.openweathermap.org/data/2.5/weather?&q=chemal
# Processing Record 269 | kavieng
# http://api.openweathermap.org/data/2.5/weather?&q=kavieng
# Processing Record 270 | pathein
# http://api.openweathermap.org/data/2.5/weather?&q=pathein
# Processing Record 271 | lakhtar
# http://api.openweathermap.org/data/2.5/weather?&q=lakhtar
# Processing Record 272 | aljezur
# http://api.openweathermap.org/data/2.5/weather?&q=aljezur
# Processing Record 273 | hasanabad
# http://api.openweathermap.org/data/2.5/weather?&q=hasanabad
# Processing Record 274 | mahenge
# http://api.openweathermap.org/data/2.5/weather?&q=mahenge
# Processing Record 275 | vostok
# http://api.openweathermap.org/data/2.5/weather?&q=vostok
# Processing Record 276 | sinegorye
# http://api.openweathermap.org/data/2.5/weather?&q=sinegorye
# Processing Record 277 | gladstone
# http://api.openweathermap.org/data/2.5/weather?&q=gladstone
# Processing Record 278 | price
# http://api.openweathermap.org/data/2.5/weather?&q=price
# Processing Record 279 | chuy
# http://api.openweathermap.org/data/2.5/weather?&q=chuy
# Processing Record 280 | ostersund
# http://api.openweathermap.org/data/2.5/weather?&q=ostersund
# Processing Record 281 | gizo
# http://api.openweathermap.org/data/2.5/weather?&q=gizo
# Processing Record 282 | chitipa
# http://api.openweathermap.org/data/2.5/weather?&q=chitipa
# Processing Record 283 | sorong
# http://api.openweathermap.org/data/2.5/weather?&q=sorong
# Processing Record 284 | goundam
# http://api.openweathermap.org/data/2.5/weather?&q=goundam
# Processing Record 285 | atambua
# http://api.openweathermap.org/data/2.5/weather?&q=atambua
# Processing Record 286 | victoria
# http://api.openweathermap.org/data/2.5/weather?&q=victoria
# Processing Record 287 | hun
# http://api.openweathermap.org/data/2.5/weather?&q=hun
# Processing Record 288 | baykit
# http://api.openweathermap.org/data/2.5/weather?&q=baykit
# Processing Record 289 | blagoyevo
# http://api.openweathermap.org/data/2.5/weather?&q=blagoyevo
# Processing Record 290 | sitia
# http://api.openweathermap.org/data/2.5/weather?&q=sitia
# Processing Record 291 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?&q=nouadhibou
# Processing Record 292 | mezen
# http://api.openweathermap.org/data/2.5/weather?&q=mezen
# Processing Record 293 | mackenzie
# http://api.openweathermap.org/data/2.5/weather?&q=mackenzie
# Processing Record 294 | shiraoi
# http://api.openweathermap.org/data/2.5/weather?&q=shiraoi
# Processing Record 295 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?&q=saint anthony
# City not found. Skipping...
# Processing Record 296 | ola
# http://api.openweathermap.org/data/2.5/weather?&q=ola
# City not found. Skipping...
# Processing Record 297 | poum
# http://api.openweathermap.org/data/2.5/weather?&q=poum
# Processing Record 298 | matay
# http://api.openweathermap.org/data/2.5/weather?&q=matay
# Processing Record 299 | woodward
# http://api.openweathermap.org/data/2.5/weather?&q=woodward
# Processing Record 300 | bireun
# http://api.openweathermap.org/data/2.5/weather?&q=bireun
# Processing Record 301 | jawhar
# http://api.openweathermap.org/data/2.5/weather?&q=jawhar
# Processing Record 302 | gari
# http://api.openweathermap.org/data/2.5/weather?&q=gari
# Processing Record 303 | kijang
# http://api.openweathermap.org/data/2.5/weather?&q=kijang
# Processing Record 304 | whyalla
# http://api.openweathermap.org/data/2.5/weather?&q=whyalla
# Processing Record 305 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?&q=port lincoln
# Processing Record 306 | nyurba
# http://api.openweathermap.org/data/2.5/weather?&q=nyurba
# Processing Record 307 | abong mbang
# http://api.openweathermap.org/data/2.5/weather?&q=abong mbang
# City not found. Skipping...
# Processing Record 308 | sangar
# http://api.openweathermap.org/data/2.5/weather?&q=sangar
# City not found. Skipping...
# Processing Record 309 | jaumave
# http://api.openweathermap.org/data/2.5/weather?&q=jaumave
# Processing Record 310 | mackay
# http://api.openweathermap.org/data/2.5/weather?&q=mackay
# Processing Record 311 | mattru
# http://api.openweathermap.org/data/2.5/weather?&q=mattru
# Processing Record 312 | mehamn
# http://api.openweathermap.org/data/2.5/weather?&q=mehamn
# Processing Record 313 | omboue
# http://api.openweathermap.org/data/2.5/weather?&q=omboue
# Processing Record 314 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?&q=ahuimanu
# Processing Record 315 | murgab
# http://api.openweathermap.org/data/2.5/weather?&q=murgab
# Processing Record 316 | vanavara
# http://api.openweathermap.org/data/2.5/weather?&q=vanavara
# Processing Record 317 | edson
# http://api.openweathermap.org/data/2.5/weather?&q=edson
# City not found. Skipping...
# Processing Record 318 | menongue
# http://api.openweathermap.org/data/2.5/weather?&q=menongue
# Processing Record 319 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?&q=bambanglipuro
# Processing Record 320 | palana
# http://api.openweathermap.org/data/2.5/weather?&q=palana
# Processing Record 321 | haimen
# http://api.openweathermap.org/data/2.5/weather?&q=haimen
# Processing Record 322 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?&q=bathsheba
# Processing Record 323 | sampit
# http://api.openweathermap.org/data/2.5/weather?&q=sampit
# Processing Record 324 | general roca
# http://api.openweathermap.org/data/2.5/weather?&q=general roca
# Processing Record 325 | lusambo
# http://api.openweathermap.org/data/2.5/weather?&q=lusambo
# Processing Record 326 | gotsu
# http://api.openweathermap.org/data/2.5/weather?&q=gotsu
# Processing Record 327 | yumen
# http://api.openweathermap.org/data/2.5/weather?&q=yumen
# Processing Record 328 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?&q=nanortalik
# City not found. Skipping...
# Processing Record 329 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?&q=cap malheureux
# Processing Record 330 | pucara
# http://api.openweathermap.org/data/2.5/weather?&q=pucara
# Processing Record 331 | east millcreek
# http://api.openweathermap.org/data/2.5/weather?&q=east millcreek
# Processing Record 332 | felanitx
# http://api.openweathermap.org/data/2.5/weather?&q=felanitx
# Processing Record 333 | kontagora
# http://api.openweathermap.org/data/2.5/weather?&q=kontagora
# Processing Record 334 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?&q=cherskiy
# City not found. Skipping...
# Processing Record 335 | chase
# http://api.openweathermap.org/data/2.5/weather?&q=chase
# Processing Record 336 | wick
# http://api.openweathermap.org/data/2.5/weather?&q=wick
# Processing Record 337 | hasaki
# http://api.openweathermap.org/data/2.5/weather?&q=hasaki
# Processing Record 338 | basco
# http://api.openweathermap.org/data/2.5/weather?&q=basco
# Processing Record 339 | krasnyy chikoy
# http://api.openweathermap.org/data/2.5/weather?&q=krasnyy chikoy
# Processing Record 340 | northam
# http://api.openweathermap.org/data/2.5/weather?&q=northam
# Processing Record 341 | ati
# http://api.openweathermap.org/data/2.5/weather?&q=ati
# Processing Record 342 | nioro
# http://api.openweathermap.org/data/2.5/weather?&q=nioro
# Processing Record 343 | lasa
# http://api.openweathermap.org/data/2.5/weather?&q=lasa
# Processing Record 344 | erdenet
# http://api.openweathermap.org/data/2.5/weather?&q=erdenet
# Processing Record 345 | kumeny
# http://api.openweathermap.org/data/2.5/weather?&q=kumeny
# Processing Record 346 | dukat
# http://api.openweathermap.org/data/2.5/weather?&q=dukat
# Processing Record 347 | barranca
# http://api.openweathermap.org/data/2.5/weather?&q=barranca
# Processing Record 348 | alugan
# http://api.openweathermap.org/data/2.5/weather?&q=alugan
# Processing Record 349 | yulara
# http://api.openweathermap.org/data/2.5/weather?&q=yulara
# Processing Record 350 | airai
# http://api.openweathermap.org/data/2.5/weather?&q=airai
# Processing Record 351 | christchurch
# http://api.openweathermap.org/data/2.5/weather?&q=christchurch
# City not found. Skipping...
# Processing Record 352 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?&q=solnechnyy
# Processing Record 353 | rocha
# http://api.openweathermap.org/data/2.5/weather?&q=rocha
# Processing Record 354 | morgan city
# http://api.openweathermap.org/data/2.5/weather?&q=morgan city
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 355 | arlit
# http://api.openweathermap.org/data/2.5/weather?&q=arlit
# Processing Record 356 | donskoye
# http://api.openweathermap.org/data/2.5/weather?&q=donskoye
# Processing Record 357 | ornes
# http://api.openweathermap.org/data/2.5/weather?&q=ornes
# Processing Record 358 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?&q=thinadhoo
# Processing Record 359 | neman
# http://api.openweathermap.org/data/2.5/weather?&q=neman
# Processing Record 360 | kassala
# http://api.openweathermap.org/data/2.5/weather?&q=kassala
# Processing Record 361 | kununurra
# http://api.openweathermap.org/data/2.5/weather?&q=kununurra
# Processing Record 362 | vargashi
# http://api.openweathermap.org/data/2.5/weather?&q=vargashi
# Processing Record 363 | amapa
# http://api.openweathermap.org/data/2.5/weather?&q=amapa
# Processing Record 364 | biella
# http://api.openweathermap.org/data/2.5/weather?&q=biella
# Processing Record 365 | san roque
# http://api.openweathermap.org/data/2.5/weather?&q=san roque
# Processing Record 366 | ocho rios
# http://api.openweathermap.org/data/2.5/weather?&q=ocho rios
# Processing Record 367 | castro
# http://api.openweathermap.org/data/2.5/weather?&q=castro
# Processing Record 368 | floro
# http://api.openweathermap.org/data/2.5/weather?&q=floro
# Processing Record 369 | port moresby
# http://api.openweathermap.org/data/2.5/weather?&q=port moresby
# Processing Record 370 | methoni
# http://api.openweathermap.org/data/2.5/weather?&q=methoni
# Processing Record 371 | luganville
# http://api.openweathermap.org/data/2.5/weather?&q=luganville
# Processing Record 372 | skibbereen
# http://api.openweathermap.org/data/2.5/weather?&q=skibbereen
# Processing Record 373 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?&q=ostrovnoy
# Processing Record 374 | mendi
# http://api.openweathermap.org/data/2.5/weather?&q=mendi
# Processing Record 375 | aklavik
# http://api.openweathermap.org/data/2.5/weather?&q=aklavik
# Processing Record 376 | panlaitan
# http://api.openweathermap.org/data/2.5/weather?&q=panlaitan
# Processing Record 377 | iskateley
# http://api.openweathermap.org/data/2.5/weather?&q=iskateley
# Processing Record 378 | isiro
# http://api.openweathermap.org/data/2.5/weather?&q=isiro
# Processing Record 379 | tornio
# http://api.openweathermap.org/data/2.5/weather?&q=tornio
# Processing Record 380 | locri
# http://api.openweathermap.org/data/2.5/weather?&q=locri
# City not found. Skipping...
# Processing Record 381 | la sarre
# http://api.openweathermap.org/data/2.5/weather?&q=la sarre
# Processing Record 382 | oyama
# http://api.openweathermap.org/data/2.5/weather?&q=oyama
# Processing Record 383 | marzuq
# http://api.openweathermap.org/data/2.5/weather?&q=marzuq
# Processing Record 384 | oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?&q=oktyabrskiy
# Processing Record 385 | yermekeyevo
# http://api.openweathermap.org/data/2.5/weather?&q=yermekeyevo
# Processing Record 386 | kankon
# http://api.openweathermap.org/data/2.5/weather?&q=kankon
# Processing Record 387 | estelle
# http://api.openweathermap.org/data/2.5/weather?&q=estelle
# Processing Record 388 | dunedin
# http://api.openweathermap.org/data/2.5/weather?&q=dunedin
# Processing Record 389 | zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?&q=zhezkazgan
# Processing Record 390 | oktyabrskoye
# http://api.openweathermap.org/data/2.5/weather?&q=oktyabrskoye
# Processing Record 391 | broken hill
# http://api.openweathermap.org/data/2.5/weather?&q=broken hill
# Processing Record 392 | ormara
# http://api.openweathermap.org/data/2.5/weather?&q=ormara
# Processing Record 393 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?&q=kaitangata
# Processing Record 394 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?&q=ixtapa
# Processing Record 395 | laguna
# http://api.openweathermap.org/data/2.5/weather?&q=laguna
# Processing Record 396 | souillac
# http://api.openweathermap.org/data/2.5/weather?&q=souillac
# Processing Record 397 | lata
# http://api.openweathermap.org/data/2.5/weather?&q=lata
# Processing Record 398 | touho
# http://api.openweathermap.org/data/2.5/weather?&q=touho
# Processing Record 399 | winnemucca
# http://api.openweathermap.org/data/2.5/weather?&q=winnemucca
# Processing Record 400 | moranbah
# http://api.openweathermap.org/data/2.5/weather?&q=moranbah
# Processing Record 401 | ayorou
# http://api.openweathermap.org/data/2.5/weather?&q=ayorou
# City not found. Skipping...
# Processing Record 402 | teya
# http://api.openweathermap.org/data/2.5/weather?&q=teya
# Processing Record 403 | varfurile
# http://api.openweathermap.org/data/2.5/weather?&q=varfurile
# City not found. Skipping...
# Processing Record 404 | manbij
# http://api.openweathermap.org/data/2.5/weather?&q=manbij
# Processing Record 405 | adrar
# http://api.openweathermap.org/data/2.5/weather?&q=adrar
# Processing Record 406 | rudnogorsk
# http://api.openweathermap.org/data/2.5/weather?&q=rudnogorsk
# Processing Record 407 | diamantino
# http://api.openweathermap.org/data/2.5/weather?&q=diamantino
# Processing Record 408 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?&q=hervey bay
# Processing Record 409 | zhanaozen
# http://api.openweathermap.org/data/2.5/weather?&q=zhanaozen
# Processing Record 410 | buin
# http://api.openweathermap.org/data/2.5/weather?&q=buin
# City not found. Skipping...
# Processing Record 411 | weener
# http://api.openweathermap.org/data/2.5/weather?&q=weener
# Processing Record 412 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?&q=nelson bay
# Processing Record 413 | herat
# http://api.openweathermap.org/data/2.5/weather?&q=herat
# Processing Record 414 | marshalltown
# http://api.openweathermap.org/data/2.5/weather?&q=marshalltown
# Processing Record 415 | crixas
# http://api.openweathermap.org/data/2.5/weather?&q=crixas
# Processing Record 416 | rabo de peixe
# http://api.openweathermap.org/data/2.5/weather?&q=rabo de peixe
# Processing Record 417 | lope de vega
# http://api.openweathermap.org/data/2.5/weather?&q=lope de vega
# Processing Record 418 | namibe
# http://api.openweathermap.org/data/2.5/weather?&q=namibe
# Processing Record 419 | dondaicha
# http://api.openweathermap.org/data/2.5/weather?&q=dondaicha
# Processing Record 420 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?&q=oranjemund
# Processing Record 421 | mahanoro
# http://api.openweathermap.org/data/2.5/weather?&q=mahanoro
# Processing Record 422 | tecoanapa
# http://api.openweathermap.org/data/2.5/weather?&q=tecoanapa
# Processing Record 423 | mamlyutka
# http://api.openweathermap.org/data/2.5/weather?&q=mamlyutka
# City not found. Skipping...
# Processing Record 424 | turan
# http://api.openweathermap.org/data/2.5/weather?&q=turan
# Processing Record 425 | alihe
# http://api.openweathermap.org/data/2.5/weather?&q=alihe
# Processing Record 426 | surgut
# http://api.openweathermap.org/data/2.5/weather?&q=surgut
# Processing Record 427 | lakatoro
# http://api.openweathermap.org/data/2.5/weather?&q=lakatoro
# Processing Record 428 | teguldet
# http://api.openweathermap.org/data/2.5/weather?&q=teguldet
# Processing Record 429 | genhe
# http://api.openweathermap.org/data/2.5/weather?&q=genhe
# City not found. Skipping...
# Processing Record 430 | wellington
# http://api.openweathermap.org/data/2.5/weather?&q=wellington
# Processing Record 431 | inza
# http://api.openweathermap.org/data/2.5/weather?&q=inza
# Processing Record 432 | lakes entrance
# http://api.openweathermap.org/data/2.5/weather?&q=lakes entrance
# Processing Record 433 | ludvika
# http://api.openweathermap.org/data/2.5/weather?&q=ludvika
# Processing Record 434 | brae
# http://api.openweathermap.org/data/2.5/weather?&q=brae
# Processing Record 435 | plouzane
# http://api.openweathermap.org/data/2.5/weather?&q=plouzane
# Processing Record 436 | sundargarh
# http://api.openweathermap.org/data/2.5/weather?&q=sundargarh
# Processing Record 437 | inhumas
# http://api.openweathermap.org/data/2.5/weather?&q=inhumas
# Processing Record 438 | san rafael del sur
# http://api.openweathermap.org/data/2.5/weather?&q=san rafael del sur
# Processing Record 439 | aquiraz
# http://api.openweathermap.org/data/2.5/weather?&q=aquiraz
# Processing Record 440 | mastic beach
# http://api.openweathermap.org/data/2.5/weather?&q=mastic beach
# Processing Record 441 | roma
# http://api.openweathermap.org/data/2.5/weather?&q=roma
# Processing Record 442 | shamary
# http://api.openweathermap.org/data/2.5/weather?&q=shamary
# City not found. Skipping...
# Processing Record 443 | vyritsa
# http://api.openweathermap.org/data/2.5/weather?&q=vyritsa
# Processing Record 444 | forbes
# http://api.openweathermap.org/data/2.5/weather?&q=forbes
# City not found. Skipping...
# Processing Record 445 | clyde river
# http://api.openweathermap.org/data/2.5/weather?&q=clyde river
# Processing Record 446 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?&q=half moon bay
# Processing Record 447 | tuscaloosa
# http://api.openweathermap.org/data/2.5/weather?&q=tuscaloosa
# Processing Record 448 | shadegan
# http://api.openweathermap.org/data/2.5/weather?&q=shadegan
# Processing Record 449 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?&q=maniitsoq
# Processing Record 450 | nicoya
# http://api.openweathermap.org/data/2.5/weather?&q=nicoya
# Processing Record 451 | macapa
# http://api.openweathermap.org/data/2.5/weather?&q=macapa
# Processing Record 452 | springdale
# http://api.openweathermap.org/data/2.5/weather?&q=springdale
# Processing Record 453 | finschhafen
# http://api.openweathermap.org/data/2.5/weather?&q=finschhafen
# Processing Record 454 | san policarpo
# http://api.openweathermap.org/data/2.5/weather?&q=san policarpo
# Processing Record 455 | koumac
# http://api.openweathermap.org/data/2.5/weather?&q=koumac
# Processing Record 456 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?&q=los llanos de aridane
# Processing Record 457 | muzhi
# http://api.openweathermap.org/data/2.5/weather?&q=muzhi
# Processing Record 458 | xinzhou
# http://api.openweathermap.org/data/2.5/weather?&q=xinzhou
# Processing Record 459 | listvyanskiy
# http://api.openweathermap.org/data/2.5/weather?&q=listvyanskiy
# Processing Record 460 | strezhevoy
# http://api.openweathermap.org/data/2.5/weather?&q=strezhevoy
# Processing Record 461 | tezu
# http://api.openweathermap.org/data/2.5/weather?&q=tezu
# Processing Record 462 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?&q=praia da vitoria
# Processing Record 463 | windhoek
# http://api.openweathermap.org/data/2.5/weather?&q=windhoek
# Processing Record 464 | isangel
# http://api.openweathermap.org/data/2.5/weather?&q=isangel
# Processing Record 465 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?&q=plettenberg bay
# Processing Record 466 | kutum
# http://api.openweathermap.org/data/2.5/weather?&q=kutum
# City not found. Skipping...
# Processing Record 467 | vila do maio
# http://api.openweathermap.org/data/2.5/weather?&q=vila do maio
# Processing Record 468 | san jeronimo
# http://api.openweathermap.org/data/2.5/weather?&q=san jeronimo
# Processing Record 469 | sabha
# http://api.openweathermap.org/data/2.5/weather?&q=sabha
# Processing Record 470 | vuktyl
# http://api.openweathermap.org/data/2.5/weather?&q=vuktyl
# Processing Record 471 | coihueco
# http://api.openweathermap.org/data/2.5/weather?&q=coihueco
# Processing Record 472 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?&q=taoudenni
# Processing Record 473 | baculin
# http://api.openweathermap.org/data/2.5/weather?&q=baculin
# Processing Record 474 | cidreira
# http://api.openweathermap.org/data/2.5/weather?&q=cidreira
# Processing Record 475 | rehti
# http://api.openweathermap.org/data/2.5/weather?&q=rehti
# Processing Record 476 | praia
# http://api.openweathermap.org/data/2.5/weather?&q=praia
# Processing Record 477 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?&q=deputatskiy
# Processing Record 478 | sabang
# http://api.openweathermap.org/data/2.5/weather?&q=sabang
# Processing Record 479 | paamiut
# http://api.openweathermap.org/data/2.5/weather?&q=paamiut
# Processing Record 480 | kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?&q=kulhudhuffushi
# Processing Record 481 | ternate
# http://api.openweathermap.org/data/2.5/weather?&q=ternate
# Processing Record 482 | bafq
# http://api.openweathermap.org/data/2.5/weather?&q=bafq
# Processing Record 483 | smirnykh
# http://api.openweathermap.org/data/2.5/weather?&q=smirnykh
# City not found. Skipping...
# Processing Record 484 | sur
# http://api.openweathermap.org/data/2.5/weather?&q=sur
# Processing Record 485 | mannarakkat
# http://api.openweathermap.org/data/2.5/weather?&q=mannarakkat
# Processing Record 486 | kailua
# http://api.openweathermap.org/data/2.5/weather?&q=kailua
# Processing Record 487 | itzehoe
# http://api.openweathermap.org/data/2.5/weather?&q=itzehoe
# Processing Record 488 | pontes e lacerda
# http://api.openweathermap.org/data/2.5/weather?&q=pontes e lacerda
# Processing Record 489 | pecos
# http://api.openweathermap.org/data/2.5/weather?&q=pecos
# Processing Record 490 | mumford
# http://api.openweathermap.org/data/2.5/weather?&q=mumford
# Processing Record 491 | muroto
# http://api.openweathermap.org/data/2.5/weather?&q=muroto
# Processing Record 492 | coihaique
# http://api.openweathermap.org/data/2.5/weather?&q=coihaique
# Processing Record 493 | karatuzskoye
# http://api.openweathermap.org/data/2.5/weather?&q=karatuzskoye
# Processing Record 494 | ferkessedougou
# http://api.openweathermap.org/data/2.5/weather?&q=ferkessedougou
# Processing Record 495 | ekibastuz
# http://api.openweathermap.org/data/2.5/weather?&q=ekibastuz
# Processing Record 496 | rio bananal
# http://api.openweathermap.org/data/2.5/weather?&q=rio bananal
# Processing Record 497 | ust-maya
# http://api.openweathermap.org/data/2.5/weather?&q=ust-maya
# Processing Record 498 | exeter
# http://api.openweathermap.org/data/2.5/weather?&q=exeter
# Processing Record 499 | saint-nazaire
# http://api.openweathermap.org/data/2.5/weather?&q=saint-nazaire
# Processing Record 500 | tucurui
# http://api.openweathermap.org/data/2.5/weather?&q=tucurui
# Processing Record 501 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?&q=ambilobe
# Processing Record 502 | bangangte
# http://api.openweathermap.org/data/2.5/weather?&q=bangangte
# Processing Record 503 | beohari
# http://api.openweathermap.org/data/2.5/weather?&q=beohari
# Processing Record 504 | novozybkov
# http://api.openweathermap.org/data/2.5/weather?&q=novozybkov
# Processing Record 505 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?&q=belyy yar
# Processing Record 506 | avera
# http://api.openweathermap.org/data/2.5/weather?&q=avera
# Processing Record 507 | presque isle
# http://api.openweathermap.org/data/2.5/weather?&q=presque isle
# Processing Record 508 | san jose de comayagua
# http://api.openweathermap.org/data/2.5/weather?&q=san jose de comayagua
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 509 | kapit
# http://api.openweathermap.org/data/2.5/weather?&q=kapit
# Processing Record 510 | xacmaz
# http://api.openweathermap.org/data/2.5/weather?&q=xacmaz
# Processing Record 511 | sayyan
# http://api.openweathermap.org/data/2.5/weather?&q=sayyan
# Processing Record 512 | amberley
# http://api.openweathermap.org/data/2.5/weather?&q=amberley
# Processing Record 513 | nowy targ
# http://api.openweathermap.org/data/2.5/weather?&q=nowy targ
# Processing Record 514 | trairi
# http://api.openweathermap.org/data/2.5/weather?&q=trairi
# City not found. Skipping...
# Processing Record 515 | clinton
# http://api.openweathermap.org/data/2.5/weather?&q=clinton
# Processing Record 516 | bonavista
# http://api.openweathermap.org/data/2.5/weather?&q=bonavista
# Processing Record 517 | eyemouth
# http://api.openweathermap.org/data/2.5/weather?&q=eyemouth
# Processing Record 518 | kupang
# http://api.openweathermap.org/data/2.5/weather?&q=kupang
# Processing Record 519 | dumka
# http://api.openweathermap.org/data/2.5/weather?&q=dumka
# Processing Record 520 | kodyma
# http://api.openweathermap.org/data/2.5/weather?&q=kodyma
# Processing Record 521 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?&q=port macquarie
# Processing Record 522 | weligama
# http://api.openweathermap.org/data/2.5/weather?&q=weligama
# Processing Record 523 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?&q=kavaratti
# City not found. Skipping...
# Processing Record 524 | peniche
# http://api.openweathermap.org/data/2.5/weather?&q=peniche
# Processing Record 525 | kawalu
# http://api.openweathermap.org/data/2.5/weather?&q=kawalu
# Processing Record 526 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?&q=batagay-alyta
# Processing Record 527 | novyy urengoy
# http://api.openweathermap.org/data/2.5/weather?&q=novyy urengoy
# Processing Record 528 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?&q=lazaro cardenas
# Processing Record 529 | dalvik
# http://api.openweathermap.org/data/2.5/weather?&q=dalvik
# Processing Record 530 | westport
# http://api.openweathermap.org/data/2.5/weather?&q=westport
# Processing Record 531 | vallenar
# http://api.openweathermap.org/data/2.5/weather?&q=vallenar
# Processing Record 532 | samarai
# http://api.openweathermap.org/data/2.5/weather?&q=samarai
# Processing Record 533 | prado
# http://api.openweathermap.org/data/2.5/weather?&q=prado
# Processing Record 534 | butterworth
# http://api.openweathermap.org/data/2.5/weather?&q=butterworth
# Processing Record 535 | micheweni
# http://api.openweathermap.org/data/2.5/weather?&q=micheweni
# Processing Record 536 | svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?&q=svetlogorsk
# Processing Record 537 | iquique
# http://api.openweathermap.org/data/2.5/weather?&q=iquique
# Processing Record 538 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?&q=batemans bay
# Processing Record 539 | helong
# http://api.openweathermap.org/data/2.5/weather?&q=helong
# Processing Record 540 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?&q=ust-nera
# City not found. Skipping...
# Processing Record 541 | manta
# http://api.openweathermap.org/data/2.5/weather?&q=manta
# Processing Record 542 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?&q=beringovskiy
# Processing Record 543 | kuytun
# http://api.openweathermap.org/data/2.5/weather?&q=kuytun
# City not found. Skipping...
# Processing Record 544 | teocaltiche
# http://api.openweathermap.org/data/2.5/weather?&q=teocaltiche
# Processing Record 545 | kpandae
# http://api.openweathermap.org/data/2.5/weather?&q=kpandae
# City not found. Skipping...
# Processing Record 546 | santa vitoria do palmar
# http://api.openweathermap.org/data/2.5/weather?&q=santa vitoria do palmar
# Processing Record 547 | ancud
# http://api.openweathermap.org/data/2.5/weather?&q=ancud
# City not found. Skipping...
# Processing Record 548 | cotonou
# http://api.openweathermap.org/data/2.5/weather?&q=cotonou
# Processing Record 549 | ulaangom
# http://api.openweathermap.org/data/2.5/weather?&q=ulaangom
# Processing Record 550 | mukdahan
# http://api.openweathermap.org/data/2.5/weather?&q=mukdahan
# Processing Record 551 | jalu
# http://api.openweathermap.org/data/2.5/weather?&q=jalu
# Processing Record 552 | tadepallegudem
# http://api.openweathermap.org/data/2.5/weather?&q=tadepallegudem
# Processing Record 553 | malumfashi
# http://api.openweathermap.org/data/2.5/weather?&q=malumfashi
# Processing Record 554 | paraiso
# http://api.openweathermap.org/data/2.5/weather?&q=paraiso
# City not found. Skipping...
# Processing Record 555 | nexo
# http://api.openweathermap.org/data/2.5/weather?&q=nexo
# Processing Record 556 | burnie
# http://api.openweathermap.org/data/2.5/weather?&q=burnie
# Processing Record 557 | colares
# http://api.openweathermap.org/data/2.5/weather?&q=colares
# Processing Record 558 | katobu
# http://api.openweathermap.org/data/2.5/weather?&q=katobu
# Processing Record 559 | mayor pablo lagerenza
# http://api.openweathermap.org/data/2.5/weather?&q=mayor pablo lagerenza
# Processing Record 560 | davila
# http://api.openweathermap.org/data/2.5/weather?&q=davila
# Processing Record 561 | lerwick
# http://api.openweathermap.org/data/2.5/weather?&q=lerwick
# Processing Record 562 | jamtara
# http://api.openweathermap.org/data/2.5/weather?&q=jamtara
# Processing Record 563 | pitogo
# http://api.openweathermap.org/data/2.5/weather?&q=pitogo
# Processing Record 564 | moron
# http://api.openweathermap.org/data/2.5/weather?&q=moron
# City not found. Skipping...
# Processing Record 565 | dauphin
# http://api.openweathermap.org/data/2.5/weather?&q=dauphin
# Processing Record 566 | muravlenko
# http://api.openweathermap.org/data/2.5/weather?&q=muravlenko

# %%
#Create and display dataframe
weather_data= pd.DataFrame({'City' : names,
                            'Cloudiness' : cloudiness,
                            'Country' : country, 
                            'Date' : dates, 
                            'Humidity' : humidity, 
                            'Lat' : lats,
                            'Lng' : lons, 
                            'Max Temp' : max_temps,  
                            'Wind Speed' : wind_speed
                           })

weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       Salalah          40      OM  1553568600        74  17.01   54.10
# 1     Saskylakh          48      RU  1553572772        74  71.97  114.09
# 2  Punta Arenas          40      CL  1553572946        65 -53.16  -70.91
# 3         Aswan           0      EG  1553569200        26  24.09   32.90
# 4          Ayan           0      TR  1553573044        62  40.67   33.60
#
#    Max Temp  Wind Speed
# 0     78.80        6.93
# 1      5.52        4.94
# 2     46.40       12.75
# 3     55.40        2.24
# 4     14.25        2.37

# %%
#export data to csv file
weather_data.to_csv("Weather Data.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Build Scatter Plot of Temp (F) vs. Latitude
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o")


plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitutde")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_MaxTemp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build Scatter Plot of Humidity (%) vs. Latitude
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o")


plt.title("City Latitude vs. Humidity (%)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitutde")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build Scatter Plot of Cloudiness (%) vs. Latitude
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o")


plt.title("City Latitude vs. Cloudiness (%)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitutde")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build Scatter Plot of Wind Speed vs. Latitude
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o")


plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitutde")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_WindSpeed.png")

# Show plot
plt.show()
